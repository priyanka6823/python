# %% [markdown]
# # file handiling

# %%
a=open('sahruk.txt','w') #write mode
a.write('data science')
a.close()

# %%
f=open('hari.txt','w')
f.write('iam from kmr')
f.close()

# %%
a=open('sharuk.txt','w')
a.write('i want learn python')
a.close()

# %%
#mode a
f=open('sharuk.txt','a')
f.write('iam from kmr')
f.close()

# %%
f=open('ram.txt','a')
f.write('this is india it is a good country')
f.close()

# %%
f=open('ram.txt','a')
f.write(' iam from kmr')
f.close()

# %%
f=open('ram.txt','r')
print(f.read())
# Out:
# india is a big country   iam from kmr

# %% [markdown]
# ## `append` change the data

# %%
a=[1,2,3,4]
print(a)
a.append(9)
print(a)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4, 9]

# %%
a=open('kamal.txt','w')
a.write('by kamal')
a.close()

# %%
# read file
a = open('kamal.txt' , 'r')
print(a.read())
# Out:
# by kamal

# %%
#read line
a = open('python.txt' , 'w')
a.write("""Python tutorial provides basic and advanced concepts of Python. Our Python tutorial is designed for beginners and professionals.

Python is a simple, general purpose, high level, and object-oriented programming language.

Python is an interpreted scripting language also. Guido Van Rossum is known as the founder of Python programming.""")
a.close()

# %%
a=open('python.txt','r')
print(a.read())
a.close()
# Out:
# Python tutorial provides basic and advanced concepts of Python. Our Python tutorial is designed for beginners and professionals.
#
# Python is a simple, general purpose, high level, and object-oriented programming language.
#
# Python is an interpreted scripting language also. Guido Van Rossum is known as the founder of Python programming.

# %%
a=open('python.txt','r')
print(a.readline())
a.close()
# Out:
# Python tutorial provides basic and advanced concepts of Python. Our Python tutorial is designed for beginners and professionals.

# %% [markdown]
# # with function

# %%
with open('datascience.txt', 'w') as k: # k plays a role like variabe
    k.write("""Python tutorial provides basic and advanced concepts of Python. Our Python tutorial is designed for beginners and professionals.

Python is a simple, general purpose, high level, and object-oriented programming language.

Python is an interpreted scripting language also. Guido Van Rossum is known as the founder of Python""")
    k.close()

# %%
with open('datascience.txt','r') as k:
  print(k.read())
  k.close()
# Out:
# Python tutorial provides basic and advanced concepts of Python. Our Python tutorial is designed for beginners and professionals.
#
# Python is a simple, general purpose, high level, and object-oriented programming language.
#
# Python is an interpreted scripting language also. Guido Van Rossum is known as the founder of Python

# %%
with open('datascience.txt','w') as k:
  k.write('\n appending data')
  k.close()

# %%
with open('datascience.txt','r') as k:
  print(k.read())
  k.close()

# %%
#Natural language processing -> the algorithms which learns from Human Language

# %%
with open('demo.txt' , 'w') as k:
    k.read('this is famous place ')

# %%
import os

# %%
os.listdir('/.') # root directory
# Out:
# ['lib64',
#  'var',
#  'bin',
#  'boot',
#  'tmp',
#  'mnt',
#  'srv',
#  'run',
#  'sys',
#  'sbin',
#  'dev',
#  'etc',
#  'opt',
#  'usr',
#  'lib32',
#  'root',
#  'home',
#  'proc',
#  'libx32',
#  'media',
#  'lib',
#  'content',
#  'untitled',
#  'kaggle',
#  '.dockerenv',
#  'datalab',
#  'tools',
#  'python-apt',
#  'python-apt.tar.xz']

# %%
os.listdir('./') # current directory
# Out:
# ['.config', 'demo.txt', '.ipynb_checkpoints', 'datascience.txt', 'sample_data']

# %% [markdown]
# # math module

# %%
import math

# %%
a=5
b=math.sqrt(a)
print(b)
# Out:
# 2.23606797749979

# %%
a=6
b=math.factorial(a)
print(b)
# Out:
# 720

# %%
pow(2,3,6)
# Out:
# 2

# %%
a=6
b=math.pow(a,2)
print(b)
# Out:
# 36.0

# %%
a=7
b=math.exp(a)
print(b)
# Out:
# 1096.6331584284585

# %%
a=10
b=math.log(a)
print(b)
# Out:
# 2.302585092994046

# %%
pow(6,3)
# Out:
# 216
